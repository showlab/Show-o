# %%
import os
os.environ['CUDA_HOME'] = '/home/jovyan/vasiliev/notebooks/Show-o/cuda_fake'

# %%
import torch
from models.modeling_showo import Showo

model = Showo(
    w_clip_vit=False,
    vocab_size=58498,
    llm_vocab_size=51200,
    llm_model_path="microsoft/phi-2",
    load_from_showo=True,
    use_moe=True,
    moe_num_experts=4,
    moe_top_k=2,
    moe_layers=6,
)


batch_size, seq_len = 2, 16
input_ids = torch.randint(0, 58498, (batch_size, seq_len))
# Out:
# /home/jovyan/vasiliev/notebooks/Show-o/.venv/lib/python3.11/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# attention implementation:  sdpa
# Replacing MLP with MoE in layers 26-31
#   num_experts=4, top_k=2
# attention implementation:  sdpa
# attention implementation:  sdpa
# attention implementation:  sdpa
# attention implementation:  sdpa
#   Layer 26: PhiMLP → MoE
# attention implementation:  sdpa
# attention implementation:  sdpa
# attention implementation:  sdpa
# attention implementation:  sdpa
#   Layer 27: PhiMLP → MoE
# attention implementation:  sdpa
# attention implementation:  sdpa
# attention implementation:  sdpa
# attention implementation:  sdpa
#   Layer 28: PhiMLP → MoE
# attention implementation:  sdpa
# attention implementation:  sdpa
# ...

# %%
with torch.no_grad():
    output = model(input_ids=input_ids)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[5], line 3
#       1 model = model.to('cpu')
#       2 with torch.no_grad():
# ----> 3     output = model(input_ids=input_ids)
#
# File ~/vasiliev/notebooks/Show-o/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/vasiliev/notebooks/Show-o/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
# ...
